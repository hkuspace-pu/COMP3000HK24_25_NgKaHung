# %% [markdown]
# # Grover Algorithm

# %%
# Built-in modules
import math
from qiskit_aer import Aer

# Imports from Qiskit
from qiskit import QuantumCircuit, transpile
from qiskit.circuit.library import GroverOperator, MCMT, ZGate
from qiskit.visualization import plot_distribution

# Imports from Qiskit Runtime
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_ibm_runtime import SamplerV2 as Sampler

import time

# %%
# To run on hardware, select the backend with the fewest number of jobs in the queue

from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(
    channel='ibm_quantum',
    instance='ibm-q/open/main',
    token='2ce8efea0ea2f41cfe2db92f4771b22c101f583f98e4871b0893c8efb5c5cb8216928ae2ab16b108f59f79c36d5b711f5203a665cb65900e384b3a452c693f4b'
)

backend = service.least_busy(operational=True, simulator=False)
backend.name
# Out:
# 'ibm_kyiv'

# %%
def grover_oracle(marked_states):
    """Build a Grover oracle for multiple marked states

    Here we assume all input marked states have the same number of bits

    Parameters:
        marked_states (str or list): Marked states of oracle

    Returns:
        QuantumCircuit: Quantum circuit representing Grover oracle
    """
    if not isinstance(marked_states, list):
        marked_states = [marked_states]
    # Compute the number of qubits in circuit
    num_qubits = len(marked_states[0])

    qc = QuantumCircuit(num_qubits)
    # Mark each target state in the input list
    for target in marked_states:
        # Flip target bit-string to match Qiskit bit-ordering
        rev_target = target[::-1]
        # Find the indices of all the '0' elements in bit-string
        zero_inds = [ind for ind in range(num_qubits) if rev_target.startswith("0", ind)]
        # Add a multi-controlled Z-gate with pre- and post-applied X-gates (open-controls)
        # where the target bit-string has a '0' entry
        qc.x(zero_inds)
        qc.compose(MCMT(ZGate(), num_qubits - 1, 1), inplace=True)
        qc.x(zero_inds)
    return qc

# %%
import random

num_qubits = 3

random_marked_state = ''.join(random.choice('01') for _ in range(num_qubits))

marked_states = [random_marked_state]

print("Random Marked State:", marked_states)

oracle = grover_oracle(marked_states)
# Out:
# Random Marked State: ['011']

# %%
grover_op = GroverOperator(oracle)
grover_op.decompose().draw(output="mpl", style="iqp")

# %%
optimal_num_iterations = math.floor(
    math.pi / (4 * math.asin(math.sqrt(len(marked_states) / 2**grover_op.num_qubits)))
)

# %%
qc = QuantumCircuit(grover_op.num_qubits)
# Create even superposition of all basis states
qc.h(range(grover_op.num_qubits))
# Apply Grover operator the optimal number of times
qc.compose(grover_op.power(optimal_num_iterations), inplace=True)
# Measure all qubits
qc.measure_all()
qc.draw(output="mpl", style="iqp")

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

circuit_isa = pm.run(qc)

# %%
simulator = Aer.get_backend('qasm_simulator')
transpiled_circuit = transpile(circuit_isa, backend=simulator)
result = simulator.run(transpiled_circuit, shots=1024).result()
# Out:
# ---------------------------------------------------------------------------
# CircuitTooWideForTarget                   Traceback (most recent call last)
# Cell In[17], line 2
#       1 simulator = Aer.get_backend('qasm_simulator')
# ----> 2 transpiled_circuit = transpile(circuit_isa, backend=simulator)
#       3 result = simulator.run(transpiled_circuit, shots=1024).result()
#
# File D:\anaconda3\Lib\site-packages\qiskit\utils\deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File D:\anaconda3\Lib\site-packages\qiskit\utils\deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
#     [... skipping similar frames: deprecate_arg.<locals>.decorator.<locals>.wrapper at line 184 (1 times)]
#
# File D:\anaconda3\Lib\site-packages\qiskit\utils\deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File D:\anaconda3\Lib\site-packages\qiskit\compiler\transpiler.py:392, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods, num_processes, qubits_initially_zero)
#     390 output_name = _parse_output_name(output_name, circuits)
#     391 coupling_map = _parse_coupling_map(coupling_map)
# --> 392 _check_circuits_coupling_map(circuits, coupling_map, backend)
#     394 # Edge cases require using the old model (loose constraints) instead of building a target,
#     395 # but we don't populate the passmanager config with loose constraints unless it's one of
#     396 # the known edge cases to control the execution path.
#     397 # Filter instruction_durations, timing_constraints, backend_properties and inst_map deprecation
#     398 with warnings.catch_warnings():
#
# File D:\anaconda3\Lib\site-packages\qiskit\compiler\transpiler.py:473, in _check_circuits_coupling_map(circuits, cmap, backend)
#     471 num_qubits = len(circuit.qubits)
#     472 if max_qubits is not None and (num_qubits > max_qubits):
# --> 473     raise CircuitTooWideForTarget(
#     474         f"Number of qubits ({num_qubits}) in {circuit.name} "
#     475         f"is greater than maximum ({max_qubits}) in the coupling_map"
#     476     )
#
# CircuitTooWideForTarget: 'Number of qubits (127) in circuit-199 is greater than maximum (29) in the coupling_map'

# %%
sampler = Sampler(mode=backend)
sampler.options.default_shots = 10_000
startTime=time.time()
result = sampler.run([circuit_isa]).result()
endTime=time.time()
measureTime=endTime-startTime
print("Time:",measureTime)
dist = result[0].data.meas.get_counts()
# Out:
# Time: 5910.944231271744

# %%
plot_distribution(dist)
